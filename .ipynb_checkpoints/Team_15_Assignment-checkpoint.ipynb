# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime
import concurrent.futures
import time

# %% [markdown]
# ## Group Assignment
# ### Team Number: XX
# ### Team Member Names:
# ### Team Strategy Chosen: __________(RISKY OR SAFE)

# %%
start = time.perf_counter()
def get_info(stock):
    temp_frame=pd.DataFrame()
    tick = yf.Ticker(stock)
    tick_hist = tick.history(start=start_date,end=end_date)
    if len(tick_hist.index) != 0:
        if tick.info['country'] == 'United States':
            if tick_hist['Volume'].mean()>= 10000:
                for need in hist_need:
                    temp_frame[need+' of '+stock]=tick_hist[need]
                return (temp_frame,stock)
    return pd.DataFrame(),""
start_date = '2021-07-02'
end_date = '2021-10-22'
hist_data = pd.DataFrame()
clean_stocks = []
hist_need = ['Open','High','Low','Close','Volume']
tick_data = pd.read_csv("Tickers.csv",names=["Tickers"])
#with concurrent.futures.ThreadPoolExecutor() as executor:
list_tick = []
for x in range(len(tick_data.index)):
    list_tick.append(tick_data['Tickers'].iloc[x])
print(list_tick)
with concurrent.futures.ThreadPoolExecutor() as executor:
    results = executor.map(get_info, list_tick)
    for result in results:
        hist_data = pd.concat([hist_data,result[0]],join='outer',axis=1)
        clean_stocks.append(result[1])
    
finish = time.perf_counter()
print(f'Finished in {round(finish-start,2)} seconds(s)')
hist_data.dropna(inplace=True)
print(clean_stocks)
hist_data.head()
# Out:
# ['AAPL', 'ABBV', 'ABT', 'ACN', 'AGN', 'AIG', 'AMZN', 'AXP', 'BA', 'BAC', 'BIIB', 'BK', 'BLK', 'BMY', 'C', 'CAT', 'CELG', 'CL', 'CMCSA', 'COF', 'COP', 'COST', 'CSCO', 'CVS', 'GM', 'GOOG', 'JPM', 'KMI', 'KO', 'LLY', 'LMT', 'MO', 'MON', 'MRK', 'MS', 'MSFT', 'NEE', 'NKE', 'ORCL', 'OXY', 'PCLN', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'RTN', 'SHOP.TO', 'SBUX', 'SLB', 'SO', 'SPG', 'T', 'TD.TO', 'TGT', 'TWX', 'TXN', 'UNH', 'UNP', 'UPS', 'USB']
# - AGN: No data found, symbol may be delisted
# - CELG: No data found, symbol may be delisted
# - PCLN: None
# - RTN: No data found, symbol may be delisted
# - TWX: No data found for this date range, symbol may be delisted
# Finished in 48.56 seconds(s)
# ['AAPL', 'ABBV', 'ABT', '', '', 'AIG', 'AMZN', 'AXP', 'BA', 'BAC', 'BIIB', 'BK', 'BLK', 'BMY', 'C', 'CAT', '', 'CL', 'CMCSA', 'COF', 'COP', 'COST', 'CSCO', 'CVS', 'GM', 'GOOG', 'JPM', 'KMI', 'KO', 'LLY', 'LMT', 'MO', 'MON', 'MRK', 'MS', 'MSFT', 'NEE', 'NKE', 'ORCL', 'OXY', '', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', '', '', 'SBUX', 'SLB', 'SO', 'SPG', 'T', '', 'TGT', '', 'TXN', 'UNH', 'UNP', 'UPS', 'USB']
#             Open of AAPL  High of AAPL  Low of AAPL  Close of AAPL  \
# Date
# 2021-07-02    137.493033    139.586842   137.343482     139.546967
# 2021-07-06    139.656634    142.727531   139.656634     141.600876
# 2021-07-07    143.116382    144.462404   142.238989     144.143356
# 2021-07-08    141.162171    143.634848   140.254853     142.817276
# 2021-07-09    142.328727    145.220162   142.229016     144.681763
#
#             Volume of AAPL  Open of ABBV  High of ABBV  Low of ABBV  \
# Date
# 2021-07-02      78852600.0    111.900746    112.848562   111.285158
# 2021-07-06     108181800.0    112.535879    113.249187   112.145027
# 2021-07-07     104911600.0    113.258966    114.294720   112.672683
# 2021-07-08     105575500.0    113.112394    114.138374   113.034222
# 2021-07-09      99890800.0    113.640040    114.646482   113.454384
#
#             Close of ABBV  Volume of ABBV  ...  Open of UPS  High of UPS  \
# Date                                       ...
# 2021-07-02     112.535881       5719500.0  ...   208.488362   210.985178
# 2021-07-06     113.083076       7172100.0  ...   209.353804   210.497753
# 2021-07-07     114.079750       6695100.0  ...   210.199328   213.800296
# 2021-07-08     113.688896       3948800.0  ...   209.214536   211.582016
# 2021-07-09     113.913635       4823400.0  ...   212.765767   213.372562
#
#             Low of UPS  Close of UPS  Volume of UPS  Open of USB  High of USB  \
# Date
# 2021-07-02  208.179993    210.418167      2172300.0    57.171395    57.300406
# 2021-07-06  207.095731    210.179428      2421300.0    56.665274    56.893526
# 2021-07-07  209.214541    213.133820      2553700.0    55.246161    56.049996
# 2021-07-08  208.796730    210.955338      2354300.0    54.700349    55.216391
# 2021-07-09  211.552179    212.795609      2050500.0    55.653043    56.605733
#
#             Low of USB  Close of USB  Volume of USB
# Date
# 2021-07-02   56.744668     57.131699      3520900.0
# 2021-07-06   55.206468     55.583572      5008700.0
# 2021-07-07   55.037761     55.563728      5125700.0
# 2021-07-08   54.253774     54.620960      5977700.0
# 2021-07-09   55.424791     56.536266      4437300.0
#
# [5 rows x 270 columns]

# %%
while True:
    if "" not in clean_stocks:
        break
    else:
        clean_stocks.remove("")
print(clean_stocks)
monthly_returns = pd.DataFrame()
for stock in clean_stocks:
    monthly_returns['Monthly Returns of '+stock] = hist_data['Close of '+stock].pct_change()*100
monthly_returns.dropna(inplace=True)
monthly_returns.head()
# Out:
# ['AAPL', 'ABBV', 'ABT', 'AIG', 'AMZN', 'AXP', 'BA', 'BAC', 'BIIB', 'BK', 'BLK', 'BMY', 'C', 'CAT', 'CL', 'CMCSA', 'COF', 'COP', 'COST', 'CSCO', 'CVS', 'GM', 'GOOG', 'JPM', 'KMI', 'KO', 'LLY', 'LMT', 'MO', 'MON', 'MRK', 'MS', 'MSFT', 'NEE', 'NKE', 'ORCL', 'OXY', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'SBUX', 'SLB', 'SO', 'SPG', 'T', 'TGT', 'TXN', 'UNH', 'UNP', 'UPS', 'USB']
#             Monthly Returns of AAPL  Monthly Returns of ABBV  \
# Date
# 2021-07-06                 1.471841                 0.486241
# 2021-07-07                 1.795526                 0.881364
# 2021-07-08                -0.919973                -0.342615
# 2021-07-09                 1.305505                 0.197679
# 2021-07-12                -0.420371                 0.900663
#
#             Monthly Returns of ABT  Monthly Returns of AIG  \
# Date
# 2021-07-06                0.660788               -2.996878
# 2021-07-07                0.883694                0.386187
# 2021-07-08               -0.508882               -4.124817
# 2021-07-09                0.402476                4.480600
# 2021-07-12               -0.776685                1.216133
#
#             Monthly Returns of AMZN  Monthly Returns of AXP  \
# Date
# 2021-07-06                 4.692707                0.629081
# 2021-07-07                 0.566963                0.837459
# 2021-07-08                 0.942218               -2.035319
# 2021-07-09                -0.323466                2.650744
# 2021-07-12                -0.021241                0.965453
#
#             Monthly Returns of BA  Monthly Returns of BAC  \
# Date
# 2021-07-06              -0.228153               -2.624553
# 2021-07-07              -1.846363               -0.798599
# 2021-07-08               2.152906               -2.440249
# 2021-07-09               1.191026                3.249103
# 2021-07-12              -0.542595                1.473522
#
#             Monthly Returns of BIIB  Monthly Returns of BK  ...  \
# Date                                                        ...
# 2021-07-06                -1.098299              -3.415290  ...
# 2021-07-07                 3.027044              -0.020208  ...
# 2021-07-08                 3.861200              -2.303969  ...
# 2021-07-09                -2.950815               3.289202  ...
# 2021-07-12                -2.546347               0.700982  ...
#
#             Monthly Returns of SLB  Monthly Returns of SO  \
# Date
# 2021-07-06               -4.940534               0.178772
# 2021-07-07               -1.572021               0.081111
# 2021-07-08               -0.488914              -0.226939
# 2021-07-09                2.161804              -0.129972
# 2021-07-12                0.096184               0.536845
#
#             Monthly Returns of SPG  Monthly Returns of T  \
# Date
# 2021-07-06               -1.535144             -0.718434
# 2021-07-07               -1.449386             -0.310138
# 2021-07-08               -0.556491             -0.809570
# 2021-07-09                3.677358              0.958127
# 2021-07-12                0.447218              0.105441
#
#             Monthly Returns of TGT  Monthly Returns of TXN  \
# Date
# 2021-07-06               -0.458275               -0.525473
# 2021-07-07                0.855578               -0.742678
# 2021-07-08                0.416077               -0.811460
# 2021-07-09                0.000000                1.078409
# 2021-07-12                1.472360                0.867191
#
#             Monthly Returns of UNH  Monthly Returns of UNP  \
# Date
# 2021-07-06                0.219863               -0.404951
# 2021-07-07                0.341241                2.028508
# 2021-07-08               -0.415389               -4.383626
# 2021-07-09                0.526891                1.534306
# 2021-07-12                0.953630               -0.212007
#
#             Monthly Returns of UPS  Monthly Returns of USB
# Date
# 2021-07-06               -0.113459               -2.709750
# 2021-07-07                1.405652               -0.035701
# 2021-07-08               -1.022119               -1.696733
# 2021-07-09                0.872351                3.506540
# 2021-07-12               -0.275804                1.070743
#
# [5 rows x 54 columns]

# %%
beta_data = pd.DataFrame()
MarketIndex='^GSPTSE'
marketing_tick = yf.Ticker(MarketIndex)
marketing_hist = marketing_tick.history(start=start_date,end=end_date)
beta_data[MarketIndex] = marketing_hist['Close'].pct_change()*100
beta_data = pd.concat([beta_data, monthly_returns],join='inner',axis=1)
MarketVar= beta_data['^GSPTSE'].var()
Beta = pd.DataFrame(beta_data.cov() / MarketVar)
beta_vals = pd.DataFrame(Beta.iloc[[0]])
beta_vals.rename(index={'^GSPTSE': 'Beta'})
beta_vals.head()
# Out:
#          ^GSPTSE  Monthly Returns of AAPL  Monthly Returns of ABBV  \
# ^GSPTSE      1.0                  1.30269                 0.413482
#
#          Monthly Returns of ABT  Monthly Returns of AIG  \
# ^GSPTSE                0.364002                2.092086
#
#          Monthly Returns of AMZN  Monthly Returns of AXP  \
# ^GSPTSE                 1.032426                1.727356
#
#          Monthly Returns of BA  Monthly Returns of BAC  \
# ^GSPTSE               1.858664                1.883553
#
#          Monthly Returns of BIIB  ...  Monthly Returns of SLB  \
# ^GSPTSE                 0.003967  ...                2.428232
#
#          Monthly Returns of SO  Monthly Returns of SPG  Monthly Returns of T  \
# ^GSPTSE               0.212841                1.949599              0.727182
#
#          Monthly Returns of TGT  Monthly Returns of TXN  \
# ^GSPTSE                1.014328                 1.17333
#
#          Monthly Returns of UNH  Monthly Returns of UNP  \
# ^GSPTSE                1.058612                1.254119
#
#          Monthly Returns of UPS  Monthly Returns of USB
# ^GSPTSE                0.669891                1.837344
#
# [1 rows x 55 columns]

# %%
correlation_values = pd.DataFrame(monthly_returns.corr())
correlation_values.head()
# Out:
#                          Monthly Returns of AAPL  Monthly Returns of ABBV  \
# Monthly Returns of AAPL                 1.000000                 0.318023
# Monthly Returns of ABBV                 0.318023                 1.000000
# Monthly Returns of ABT                  0.323352                 0.208383
# Monthly Returns of AIG                  0.312570                 0.206090
# Monthly Returns of AMZN                 0.482592                 0.238915
#
#                          Monthly Returns of ABT  Monthly Returns of AIG  \
# Monthly Returns of AAPL                0.323352                0.312570
# Monthly Returns of ABBV                0.208383                0.206090
# Monthly Returns of ABT                 1.000000               -0.103547
# Monthly Returns of AIG                -0.103547                1.000000
# Monthly Returns of AMZN                0.197585                0.019819
#
#                          Monthly Returns of AMZN  Monthly Returns of AXP  \
# Monthly Returns of AAPL                 0.482592                0.385411
# Monthly Returns of ABBV                 0.238915                0.258852
# Monthly Returns of ABT                  0.197585               -0.077468
# Monthly Returns of AIG                  0.019819                0.650355
# Monthly Returns of AMZN                 1.000000                0.222964
#
#                          Monthly Returns of BA  Monthly Returns of BAC  \
# Monthly Returns of AAPL               0.273466                0.264025
# Monthly Returns of ABBV               0.162149                0.265296
# Monthly Returns of ABT               -0.150257               -0.121351
# Monthly Returns of AIG                0.496899                0.779164
# Monthly Returns of AMZN               0.318963                0.149246
#
#                          Monthly Returns of BIIB  Monthly Returns of BK  ...  \
# Monthly Returns of AAPL                 0.195729               0.296811  ...
# Monthly Returns of ABBV                 0.260402               0.308866  ...
# Monthly Returns of ABT                  0.194529              -0.041574  ...
# Monthly Returns of AIG                 -0.165142               0.750009  ...
# Monthly Returns of AMZN                 0.159312               0.038817  ...
#
#                          Monthly Returns of SLB  Monthly Returns of SO  \
# Monthly Returns of AAPL                0.122023               0.240007
# Monthly Returns of ABBV                0.189968               0.130398
# Monthly Returns of ABT                -0.181944               0.411580
# Monthly Returns of AIG                 0.536342               0.153636
# Monthly Returns of AMZN                0.131076               0.003642
#
#                          Monthly Returns of SPG  Monthly Returns of T  \
# Monthly Returns of AAPL                0.437226              0.403004
# Monthly Returns of ABBV                0.080086              0.481659
# Monthly Returns of ABT                -0.071825              0.176052
# Monthly Returns of AIG                 0.537380              0.575011
# Monthly Returns of AMZN                0.202460              0.166325
#
#                          Monthly Returns of TGT  Monthly Returns of TXN  \
# Monthly Returns of AAPL                0.425577                0.315897
# Monthly Returns of ABBV                0.201192                0.252978
# Monthly Returns of ABT                 0.262793                0.206312
# Monthly Returns of AIG                 0.188080                0.377124
# Monthly Returns of AMZN                0.325342                0.216874
#
#                          Monthly Returns of UNH  Monthly Returns of UNP  \
# Monthly Returns of AAPL                0.459222                0.413400
# Monthly Returns of ABBV                0.402336                0.264811
# Monthly Returns of ABT                 0.368904                0.081460
# Monthly Returns of AIG                 0.289966                0.570082
# Monthly Returns of AMZN                0.124677                0.087267
#
#                          Monthly Returns of UPS  Monthly Returns of USB
# Monthly Returns of AAPL                0.353516                0.266569
# Monthly Returns of ABBV                0.235714                0.289612
# Monthly Returns of ABT                 0.251059               -0.142188
# Monthly Returns of AIG                 0.270433                0.750046
# Monthly Returns of AMZN                0.254567                0.097493
#
# [5 rows x 54 columns]

# %%
monthly_returns['Monthly Returns of AAPL'].std(axis=0,skipna=True)
# Out:
# 1.2797322011751373

# %%
list_std = []
for stock in clean_stocks:
    list_std.append(("STD of "+stock, monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True)))
pd.DataFrame(list_std).head()
# Out:
#              0         1
# 0  STD of AAPL  1.279732
# 1  STD of ABBV  1.257231
# 2   STD of ABT  1.041513
# 3   STD of AIG  1.879931
# 4  STD of AMZN  1.563713

# %% [markdown]
# ## Contribution Declaration
#
# The following team members made a meaningful contribution to this assignment:
#
# Insert Names Here.
