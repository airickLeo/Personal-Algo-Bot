# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime
import concurrent.futures
import time
import random

# %% [markdown]
# ## Group Assignment
# ### Team Number: XX
# ### Team Member Names:
# ### Team Strategy Chosen: __________(RISKY OR SAFE)

# %%
##bing s
start = time.perf_counter()
def get_info(stock):
    temp_frame=pd.DataFrame()
    tick = yf.Ticker(stock)
    tick_hist = tick.history(start=start_date,end=end_date)
    if len(tick_hist.index) != 0:
        tick_info = tick.info
        if tick_info['currency'] == 'USD':
            if tick_hist['Volume'].mean()>= 10000:
                for need in hist_need:
                    temp_frame[need+' of '+stock]=tick_hist[need]
                return (temp_frame,stock, tick_info['sector'])
    return pd.DataFrame(),'',''
start_date = '2021-07-02'
end_date = '2021-10-22'
hist_data = pd.DataFrame()
clean_stocks = []
industry_list = []
hist_need = ['Open','High','Low','Close','Volume']
tick_data = pd.read_csv("Tickers.csv",names=["Tickers"])
#with concurrent.futures.ThreadPoolExecutor() as executor:
list_tick = []
for x in range(len(tick_data.index)):
    list_tick.append(tick_data['Tickers'].iloc[x])
print(list_tick)
with concurrent.futures.ThreadPoolExecutor() as executor:
    results = executor.map(get_info, list_tick)
    for result in results:
        hist_data = pd.concat([hist_data,result[0]],join='outer',axis=1)
        clean_stocks.append(result[1])
        industry_list.append(result[2])
while True:
    if "" not in clean_stocks:
        break
    else:
        industry_list.remove("")
        clean_stocks.remove("")
finish = time.perf_counter()
print(f'Finished in {round(finish-start,2)} seconds(s)')
hist_data.dropna(inplace=True)
print(clean_stocks)
hist_data.head()
# Out:
# ['AAPL', 'ABBV', 'ABT', 'ACN', 'AGN', 'AIG', 'AMZN', 'AXP', 'BA', 'BAC', 'BIIB', 'BK', 'BLK', 'BMY', 'C', 'CAT', 'CELG', 'CL', 'CMCSA', 'COF', 'COP', 'COST', 'CSCO', 'CVS', 'GM', 'GOOG', 'JPM', 'KMI', 'KO', 'LLY', 'LMT', 'MO', 'MON', 'MRK', 'MS', 'MSFT', 'NEE', 'NKE', 'ORCL', 'OXY', 'PCLN', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'RTN', 'SHOP.TO', 'SBUX', 'SLB', 'SO', 'SPG', 'T', 'TD.TO', 'TGT', 'TWX', 'TXN', 'UNH', 'UNP', 'UPS', 'USB']
# - AGN: No data found, symbol may be delisted
# - CELG: No data found, symbol may be delisted
# - PCLN: No data found for this date range, symbol may be delisted
# - RTN: No data found, symbol may be delisted
# - TWX: No data found for this date range, symbol may be delisted
# Finished in 26.61 seconds(s)
# ['AAPL', 'ABBV', 'ABT', 'ACN', 'AIG', 'AMZN', 'AXP', 'BA', 'BAC', 'BIIB', 'BK', 'BLK', 'BMY', 'C', 'CAT', 'CL', 'CMCSA', 'COF', 'COP', 'COST', 'CSCO', 'CVS', 'GM', 'GOOG', 'JPM', 'KMI', 'KO', 'LLY', 'LMT', 'MO', 'MON', 'MRK', 'MS', 'MSFT', 'NEE', 'NKE', 'ORCL', 'OXY', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'SBUX', 'SLB', 'SO', 'SPG', 'T', 'TGT', 'TXN', 'UNH', 'UNP', 'UPS', 'USB']
#             Open of AAPL  High of AAPL  Low of AAPL  Close of AAPL  \
# Date
# 2021-07-02    137.493033    139.586842   137.343482     139.546967
# 2021-07-06    139.656634    142.727531   139.656634     141.600876
# 2021-07-07    143.116382    144.462404   142.238989     144.143356
# 2021-07-08    141.162171    143.634848   140.254853     142.817276
# 2021-07-09    142.328727    145.220162   142.229016     144.681763
#
#             Volume of AAPL  Open of ABBV  High of ABBV  Low of ABBV  \
# Date
# 2021-07-02      78852600.0    111.900746    112.848562   111.285158
# 2021-07-06     108181800.0    112.535879    113.249187   112.145027
# 2021-07-07     104911600.0    113.258966    114.294720   112.672683
# 2021-07-08     105575500.0    113.112394    114.138374   113.034222
# 2021-07-09      99890800.0    113.640040    114.646482   113.454384
#
#             Close of ABBV  Volume of ABBV  ...  Open of UPS  High of UPS  \
# Date                                       ...
# 2021-07-02     112.535881       5719500.0  ...   207.463364   209.947906
# 2021-07-06     113.083076       7172100.0  ...   208.324553   209.462879
# 2021-07-07     114.079750       6695100.0  ...   209.165919   212.749183
# 2021-07-08     113.688896       3948800.0  ...   208.185954   210.541795
# 2021-07-09     113.913635       4823400.0  ...   211.719726   212.323537
#
#             Low of UPS  Close of UPS  Volume of UPS  Open of USB  High of USB  \
# Date
# 2021-07-02  207.156512    209.383682      2172300.0    57.171395    57.300406
# 2021-07-06  206.077582    209.146118      2421300.0    56.665274    56.893526
# 2021-07-07  208.185974    212.085983      2553700.0    55.246161    56.049996
# 2021-07-08  207.770203    209.918198      2354300.0    54.700349    55.216391
# 2021-07-09  210.512104    211.749420      2050500.0    55.653043    56.605733
#
#             Low of USB  Close of USB  Volume of USB
# Date
# 2021-07-02   56.744668     57.131699      3520900.0
# 2021-07-06   55.206468     55.583572      5008700.0
# 2021-07-07   55.037761     55.563728      5125700.0
# 2021-07-08   54.253774     54.620960      5977700.0
# 2021-07-09   55.424791     56.536266      4437300.0
#
# [5 rows x 275 columns]

# %%
def get_daily_returns(list_of_stock):
    monthly_returns = pd.DataFrame()
    for stock in list_of_stock:
        monthly_returns['Monthly Returns of '+stock] = hist_data['Close of '+stock].pct_change()*100
    monthly_returns.dropna(inplace=True)
    return monthly_returns
def get_beta_total(hello):
    tot = 0
    for x in range (len(hello)):
        tot+= beta_vals['Monthly Returns of '+hello[x]]
    return (tot/len(hello)).iloc[0]
def get_average_std(bye):
    tot = 0
    for x in range (len(bye)):
        tot+= monthly_returns['Monthly Returns of '+bye[x]].std(axis=0,skipna=True)
    return (tot/len(bye))
def get_alpha(stocks_lst):
    # Get the current beta column
    column_counter = 1

    alpha = pd.DataFrame()
    for stock in stocks_lst:
        alpha['Alpha '+stock] = monthly_returns['Monthly Returns of '+stock] - ((monthly_returns['Monthly Returns of '+stock].mean()) * beta_vals.iloc[0, column_counter])
        column_counter += 1

    alpha.head()

    # Calculate the mean of the alpha

 #   for stock in stocks_lst:
  #      alpha_mean.append(alpha['Alpha ' + stock].mean()) 

   # positive_counter = 0
    #negative_counter = 0

 #   for i in range(len(alpha_mean)):
  #      if(alpha_mean[i] >= 0):
   #         positive_counter += 1
#
 #       else:
  #          negative_counter += 1
    return alpha
# MDD Equation: (Peak Value - Trough Value) / Peak Value
def get_mdd(stocks):

    mdd = []

    for x in range (len(stocks)):

        trough = min(hist_data['Low of '+stocks[x]])
        peak = max(hist_data['High of '+stocks[x]])

        mdd.append((((peak - trough) / peak)))

    return mdd

# %%
monthly_returns = get_daily_returns(clean_stocks)
monthly_returns.head()
# Out:
#             Monthly Returns of AAPL  Monthly Returns of ABBV  \
# Date
# 2021-07-06                 1.471841                 0.486241
# 2021-07-07                 1.795526                 0.881364
# 2021-07-08                -0.919973                -0.342615
# 2021-07-09                 1.305505                 0.197679
# 2021-07-12                -0.420381                 0.900663
#
#             Monthly Returns of ABT  Monthly Returns of ACN  \
# Date
# 2021-07-06                0.660795                0.183700
# 2021-07-07                0.883694                1.378522
# 2021-07-08               -0.508889               -0.148580
# 2021-07-09                0.402476                1.122430
# 2021-07-12               -0.776679               -0.335861
#
#             Monthly Returns of AIG  Monthly Returns of AMZN  \
# Date
# 2021-07-06               -2.996878                 4.692707
# 2021-07-07                0.386187                 0.566963
# 2021-07-08               -4.124817                 0.942218
# 2021-07-09                4.480600                -0.323466
# 2021-07-12                1.216133                -0.021241
#
#             Monthly Returns of AXP  Monthly Returns of BA  \
# Date
# 2021-07-06                0.629081              -0.228153
# 2021-07-07                0.837459              -1.846363
# 2021-07-08               -2.035319               2.152906
# 2021-07-09                2.650744               1.191026
# 2021-07-12                0.965453              -0.542595
#
#             Monthly Returns of BAC  Monthly Returns of BIIB  ...  \
# Date                                                         ...
# 2021-07-06               -2.624553                -1.098299  ...
# 2021-07-07               -0.798599                 3.027044  ...
# 2021-07-08               -2.440249                 3.861200  ...
# 2021-07-09                3.249103                -2.950815  ...
# 2021-07-12                1.473522                -2.546347  ...
#
#             Monthly Returns of SLB  Monthly Returns of SO  \
# Date
# 2021-07-06               -4.940534               0.178772
# 2021-07-07               -1.572021               0.081111
# 2021-07-08               -0.488914              -0.226939
# 2021-07-09                2.161804              -0.129972
# 2021-07-12                0.096184               0.536845
#
#             Monthly Returns of SPG  Monthly Returns of T  \
# Date
# 2021-07-06               -1.535144             -0.718435
# 2021-07-07               -1.449386             -0.310134
# 2021-07-08               -0.556491             -0.809573
# 2021-07-09                3.677358              0.958130
# 2021-07-12                0.447218              0.105440
#
#             Monthly Returns of TGT  Monthly Returns of TXN  \
# Date
# 2021-07-06               -0.458268               -0.525472
# 2021-07-07                0.855572               -0.742682
# 2021-07-08                0.416077               -0.811455
# 2021-07-09                0.000000                1.078407
# 2021-07-12                1.472372                0.867193
#
#             Monthly Returns of UNH  Monthly Returns of UNP  \
# Date
# 2021-07-06                0.219863               -0.404951
# 2021-07-07                0.341241                2.028508
# 2021-07-08               -0.415389               -4.383626
# 2021-07-09                0.526891                1.534306
# 2021-07-12                0.953630               -0.212007
#
#             Monthly Returns of UPS  Monthly Returns of USB
# Date
# 2021-07-06               -0.113459               -2.709750
# 2021-07-07                1.405651               -0.035701
# 2021-07-08               -1.022126               -1.696733
# 2021-07-09                0.872351                3.506540
# 2021-07-12               -0.275798                1.070743
#
# [5 rows x 55 columns]

# %%
beta_data = pd.DataFrame()
MarketIndex='^GSPTSE'
marketing_tick = yf.Ticker(MarketIndex)
marketing_hist = marketing_tick.history(start=start_date,end=end_date)
beta_data[MarketIndex] = marketing_hist['Close'].pct_change()*100
beta_data = pd.concat([beta_data, monthly_returns],join='inner',axis=1)
MarketVar= beta_data['^GSPTSE'].var()
Beta = pd.DataFrame(beta_data.cov() / MarketVar)
beta_vals = pd.DataFrame(Beta.iloc[[0]])
beta_vals.rename(index={'^GSPTSE': 'Beta'})
beta_vals.head()
# Out:
#          ^GSPTSE  Monthly Returns of AAPL  Monthly Returns of ABBV  \
# ^GSPTSE      1.0                  1.30269                 0.413482
#
#          Monthly Returns of ABT  Monthly Returns of ACN  \
# ^GSPTSE                0.364003                0.995564
#
#          Monthly Returns of AIG  Monthly Returns of AMZN  \
# ^GSPTSE                2.092086                 1.032426
#
#          Monthly Returns of AXP  Monthly Returns of BA  \
# ^GSPTSE                1.727356               1.858664
#
#          Monthly Returns of BAC  ...  Monthly Returns of SLB  \
# ^GSPTSE                1.883553  ...                2.428232
#
#          Monthly Returns of SO  Monthly Returns of SPG  Monthly Returns of T  \
# ^GSPTSE               0.212841                1.949599              0.733672
#
#          Monthly Returns of TGT  Monthly Returns of TXN  \
# ^GSPTSE                1.014328                1.173329
#
#          Monthly Returns of UNH  Monthly Returns of UNP  \
# ^GSPTSE                1.058612                1.254119
#
#          Monthly Returns of UPS  Monthly Returns of USB
# ^GSPTSE                0.669891                1.837344
#
# [1 rows x 56 columns]

# %%
start = time.perf_counter()
tech_list = []
health_list = []
industrial_list = []
finance_list = []
defensive_list = []
cyclical_list = []
real_estate_list = []
energy_list = []
materials_list = []
communication_list = []
utilities_list = []

for (industry,stock) in zip(industry_list,clean_stocks):
    if industry == "Technology":
        tech_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Healthcare":
        health_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Industrials":
        industrial_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Financial Services":
        finance_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Consumer Defensive":
        defensive_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Consumer Cyclical":
        cyclical_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Real Estate":
        real_estate_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Energy":
        energy_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Basic Materials":
        materials_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Communication Services":
        communication_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
    if industry == "Utilities":
        utilities_list.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),stock))
list_of_industries = [tech_list,health_list,industrial_list,finance_list,defensive_list,cyclical_list,real_estate_list,energy_list,materials_list,communication_list,utilities_list]

finish = time.perf_counter()
print(f'Finished in {round(finish-start,2)} seconds(s)')
# Out:
# Finished in 0.0 seconds(s)

# %%
tech_list.sort()
health_list.sort()
industrial_list.sort()
finance_list.sort()
defensive_list.sort()
cyclical_list.sort()
real_estate_list.sort()
energy_list.sort()
materials_list.sort()
communication_list.sort()
utilities_list.sort()

# %%
total_list = []
if len(tech_list)!=0:
    total_list.append(tech_list[0][1])
    
if len(health_list)!=0:
    total_list.append(health_list[0][1])
    
if len(industrial_list)!=0:
    total_list.append(industrial_list[0][1])
    
if len(finance_list)!=0:
    total_list.append(finance_list[0][1])
    
if len(defensive_list)!=0:
    total_list.append(defensive_list[0][1])
    
if len(cyclical_list)!=0:
    total_list.append(cyclical_list[0][1])
    
if len(real_estate_list)!=0:
    total_list.append(real_estate_list[0][1])
    
if len(energy_list)!=0:
    total_list.append(energy_list[0][1])
    
if len(materials_list)!=0:
    total_list.append(materials_list[0][1])
    
if len(communication_list)!=0:
    total_list.append(communication_list[0][1])
    
if len(utilities_list)!=0:
    total_list.append(utilities_list[0][1])

# %%
total_list
# Out:
# ['CSCO', 'BMY', 'LMT', 'MON', 'PG', 'SBUX', 'SPG', 'KMI', 'T', 'SO']

# %%
alpha_mean = []
alpha = get_alpha(total_list)
alpha.head()
# Out:
#             Alpha CSCO  Alpha BMY  Alpha LMT  Alpha MON  Alpha PG  Alpha SBUX  \
# Date
# 2021-07-06   -1.135069  -0.371743  -0.733433   0.762531 -0.054235    0.654463
# 2021-07-07    0.439370   0.811527   1.275998  -0.014267  0.637012    1.211754
# 2021-07-08   -0.089126  -0.593890  -0.922573   0.181006 -0.127706   -0.988317
# 2021-07-09    0.812122   0.781099   0.845405  -0.896403 -0.076603    1.269391
# 2021-07-12   -1.038144   0.582584  -1.048754   0.368634 -0.032825    0.836169
#
#             Alpha SPG  Alpha KMI   Alpha T  Alpha SO
# Date
# 2021-07-06  -1.839876  -0.616698 -0.496046  0.178476
# 2021-07-07  -1.754118  -0.675869 -0.087746  0.080816
# 2021-07-08  -0.861223  -0.627016 -0.587185 -0.227235
# 2021-07-09   3.372626   2.835160  1.180519 -0.130268
# 2021-07-12   0.142485  -0.720083  0.327828  0.536550

# %%
mdd = get_mdd(total_list)
mdd
# Out:
# [0.1315745272407484,
#  0.18105057874970099,
#  0.12263098504021946,
#  0.034170870261855966,
#  0.08636826787558043,
#  0.1305045609406697,
#  0.21786154608093122,
#  0.17537307844185201,
#  0.1154308691397112,
#  0.10941946845955973,
#  0.08277501162873176,
#  0.09337762531990355,
#  0.12703468909507792,
#  0.17226242461532615,
#  0.11796454532568854,
#  0.1496464014797871,
#  0.1255246271586977,
#  0.1532912997203599,
#  0.13657154188285464,
#  0.09920193451568222]

# %%
for x in range (len(total_list)):
    clean_stocks.remove(total_list[x])

# %%
total_list
# Out:
# ['CSCO', 'BMY', 'LMT', 'MON', 'PG', 'SBUX', 'SPG', 'KMI', 'T', 'SO']

# %%
list_of_beta = []
for stock in clean_stocks:
    list_of_beta.append((monthly_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),beta_vals["Monthly Returns of "+stock].iloc[0],stock))
list_of_beta.sort()
list_of_beta
# Out:
# [(0.7688321597213277, 0.4999981723218368, 'KO'),
#  (0.8070678497721255, 0.27208094687927487, 'PEP'),
#  (0.9473982893659325, 0.1479497575862508, 'CL'),
#  (0.9523077719862846, 0.5814648713566358, 'COST'),
#  (1.0415131105322977, 0.36400286927796205, 'ABT'),
#  (1.046658278251328, 0.9955638582968797, 'ACN'),
#  (1.0987572408075144, 1.0660842732172688, 'MSFT'),
#  (1.152816727036022, 0.35793174019028534, 'NEE'),
#  (1.1976737036390077, 1.3367436601444522, 'GOOG'),
#  (1.1998659276253096, 0.8655149801803501, 'CVS'),
#  (1.2195931497649366, 0.8573309852082692, 'MO'),
#  (1.2264110981153888, 1.0143275478309974, 'TGT'),
#  (1.2565351315580555, 0.649599309935191, 'PM'),
#  (1.2572305193191413, 0.41348223765196035, 'ABBV'),
#  (1.263780051997507, 1.2541187384913304, 'UNP'),
#  (1.2797325890784927, 1.3026896111532988, 'AAPL'),
#  (1.3080834411931583, 1.058612109724245, 'UNH'),
#  (1.3491543295133908, 1.1733291795709087, 'TXN'),
#  (1.3514651550070829, 0.9429236073098203, 'NKE'),
#  (1.3799141849863301, 0.7317051845797139, 'ORCL'),
#  (1.3929226476324046, 0.6698908022987918, 'UPS'),
#  (1.425398463040032, 1.2183216301292423, 'QCOM'),
#  (1.451154991227771, 0.2386657543765585, 'MRK'),
#  (1.458890171862854, 1.953567380714697, 'BLK'),
#  (1.4692936904674172, 1.634853101319019, 'JPM'),
#  (1.505326808208129, 0.3768108098926118, 'LLY'),
#  (1.5376108365137382, 1.7362896781972195, 'C'),
#  (1.5392237964898818, 1.115277809380915, 'CMCSA'),
#  (1.5637127299496691, 1.0324256573742714, 'AMZN'),
#  (1.5681185091506769, 0.35727104322740516, 'PFE'),
#  (1.569258960014471, 1.979582080914751, 'MS'),
#  (1.6109738701516303, 1.9600048130316443, 'CAT'),
#  (1.6212278034264715, 1.7273559393131996, 'AXP'),
#  (1.6283865880970805, 1.8404252542885084, 'BK'),
#  (1.660712862696671, 1.8373439325697174, 'USB'),
#  (1.7018690474372322, 1.8835532278011204, 'BAC'),
#  (1.823423930144898, 0.003966881260423076, 'BIIB'),
#  (1.8799307541099626, 2.0920864397016556, 'AIG'),
#  (1.9111026766258383, 1.1512659774085592, 'PYPL'),
#  (1.9358507855825613, 1.8586638746810982, 'BA'),
#  (2.0157621501453415, 1.8684529185920162, 'COF'),
#  (2.189885854331878, 1.8876452050935195, 'COP'),
#  (2.244864406408639, 1.9881487772513387, 'GM'),
#  (2.552417391377547, 2.428231763249824, 'SLB'),
#  (3.514349972241326, 3.337166093552582, 'OXY')]

# %%
threshold = 0
index = 0
while threshold < len(clean_stocks):
    if len(total_list) == 20:
        break
    beta_temp = get_beta_total(total_list)
    std_temp = get_average_std(total_list)
    beta_stock = list_of_beta[threshold][1]
    std_stock = list_of_beta[threshold][0]
    stock = list_of_beta[threshold][2]
#    print(std_temp,std_stock)
    if beta_stock <= beta_temp and std_stock < std_temp:
        total_list.append(stock)
        clean_stocks.remove(stock)
        list_of_beta.pop(threshold)
        threshold-=1
    threshold+=1
counting = 0
print(len(total_list))
while len(total_list) != 20:
    total_list.append(list_of_beta[0][2])
    list_of_beta.pop(0)
print(total_list)
# Out:
# 14
# ['CSCO', 'BMY', 'LMT', 'MON', 'PG', 'SBUX', 'SPG', 'KMI', 'T', 'SO', 'KO', 'PEP', 'CL', 'COST', 'ABT', 'ACN', 'MSFT', 'NEE', 'GOOG', 'CVS']

# %%
final_returns = get_daily_returns(total_list)
final_returns.head()
# Out:
#             Monthly Returns of CSCO  Monthly Returns of BMY  \
# Date
# 2021-07-06                -1.045943               -0.448087
# 2021-07-07                 0.528496                0.735182
# 2021-07-08                 0.000000               -0.670234
# 2021-07-09                 0.901248                0.704755
# 2021-07-12                -0.949018                0.506239
#
#             Monthly Returns of LMT  Monthly Returns of MON  \
# Date
# 2021-07-06               -0.739197                0.776798
# 2021-07-07                1.270234                0.000000
# 2021-07-08               -0.928338                0.195273
# 2021-07-09                0.839640               -0.882137
# 2021-07-12               -1.054519                0.382901
#
#             Monthly Returns of PG  Monthly Returns of SBUX  \
# Date
# 2021-07-06               0.058867                 0.661052
# 2021-07-07               0.750114                 1.218342
# 2021-07-08              -0.014604                -0.981729
# 2021-07-09               0.036499                 1.275979
# 2021-07-12               0.080277                 0.842758
#
#             Monthly Returns of SPG  Monthly Returns of KMI  \
# Date
# 2021-07-06               -1.535144               -0.700057
# 2021-07-07               -1.449386               -0.759228
# 2021-07-08               -0.556491               -0.710375
# 2021-07-09                3.677358                2.751800
# 2021-07-12                0.447218               -0.803443
#
#             Monthly Returns of T  Monthly Returns of SO  \
# Date
# 2021-07-06             -0.718435               0.178772
# 2021-07-07             -0.310134               0.081111
# 2021-07-08             -0.809573              -0.226939
# 2021-07-09              0.958130              -0.129972
# 2021-07-12              0.105440               0.536845
#
#             Monthly Returns of KO  Monthly Returns of PEP  \
# Date
# 2021-07-06              -0.553709                0.147743
# 2021-07-07               0.816627                0.442553
# 2021-07-08              -0.349777                0.046739
# 2021-07-09               0.609640               -0.253569
# 2021-07-12               0.036727                0.020062
#
#             Monthly Returns of CL  Monthly Returns of COST  \
# Date
# 2021-07-06               0.330487                -0.020058
# 2021-07-07               0.841774                 1.459163
# 2021-07-08              -0.387135                 0.610359
# 2021-07-09               0.109306                 1.282082
# 2021-07-12               0.606580                -1.088822
#
#             Monthly Returns of ABT  Monthly Returns of ACN  \
# Date
# 2021-07-06                0.660795                0.183700
# 2021-07-07                0.883694                1.378522
# 2021-07-08               -0.508889               -0.148580
# 2021-07-09                0.402476                1.122430
# 2021-07-12               -0.776679               -0.335861
#
#             Monthly Returns of MSFT  Monthly Returns of NEE  \
# Date
# 2021-07-06                 0.003608                1.144311
# 2021-07-07                 0.817539                0.266215
# 2021-07-08                -0.896646               -0.265509
# 2021-07-09                 0.187444               -0.186339
# 2021-07-12                -0.223066                0.133346
#
#             Monthly Returns of GOOG  Monthly Returns of CVS
# Date
# 2021-07-06                 0.817286               -1.516439
# 2021-07-07                 0.236190                0.197094
# 2021-07-08                -0.692280               -1.376927
# 2021-07-09                 0.307715                1.371226
# 2021-07-12                 0.763655                0.614853

# %%
correlation_values = pd.DataFrame(final_returns.corr())
correlation_values.head()
# Out:
#                          Monthly Returns of CSCO  Monthly Returns of BMY  \
# Monthly Returns of CSCO                 1.000000                0.431783
# Monthly Returns of BMY                  0.431783                1.000000
# Monthly Returns of LMT                  0.270445                0.268171
# Monthly Returns of MON                  0.153152                0.032377
# Monthly Returns of PG                   0.413716                0.349729
#
#                          Monthly Returns of LMT  Monthly Returns of MON  \
# Monthly Returns of CSCO                0.270445                0.153152
# Monthly Returns of BMY                 0.268171                0.032377
# Monthly Returns of LMT                 1.000000               -0.090981
# Monthly Returns of MON                -0.090981                1.000000
# Monthly Returns of PG                  0.044505                0.026128
#
#                          Monthly Returns of PG  Monthly Returns of SBUX  \
# Monthly Returns of CSCO               0.413716                 0.332275
# Monthly Returns of BMY                0.349729                 0.173074
# Monthly Returns of LMT                0.044505                 0.266573
# Monthly Returns of MON                0.026128                 0.141571
# Monthly Returns of PG                 1.000000                 0.198295
#
#                          Monthly Returns of SPG  Monthly Returns of KMI  \
# Monthly Returns of CSCO                0.378010                0.273294
# Monthly Returns of BMY                 0.170115                0.051525
# Monthly Returns of LMT                 0.261668                0.319884
# Monthly Returns of MON                 0.013273               -0.041035
# Monthly Returns of PG                  0.074273               -0.002846
#
#                          Monthly Returns of T  Monthly Returns of SO  \
# Monthly Returns of CSCO              0.412120               0.229746
# Monthly Returns of BMY               0.423604               0.273545
# Monthly Returns of LMT               0.323002               0.123065
# Monthly Returns of MON               0.003940              -0.040426
# Monthly Returns of PG                0.228960               0.464961
#
#                          Monthly Returns of KO  Monthly Returns of PEP  \
# Monthly Returns of CSCO               0.469199                0.375479
# Monthly Returns of BMY                0.352593                0.338782
# Monthly Returns of LMT                0.294585                0.233500
# Monthly Returns of MON                0.045740                0.071291
# Monthly Returns of PG                 0.552413                0.631309
#
#                          Monthly Returns of CL  Monthly Returns of COST  \
# Monthly Returns of CSCO               0.254952                 0.427872
# Monthly Returns of BMY                0.301257                 0.223678
# Monthly Returns of LMT                0.104034                 0.266454
# Monthly Returns of MON               -0.020418                 0.067134
# Monthly Returns of PG                 0.415836                 0.323990
#
#                          Monthly Returns of ABT  Monthly Returns of ACN  \
# Monthly Returns of CSCO                0.345192                0.584371
# Monthly Returns of BMY                 0.388126                0.420419
# Monthly Returns of LMT                 0.047145                0.308594
# Monthly Returns of MON                 0.063011                0.119582
# Monthly Returns of PG                  0.397196                0.385522
#
#                          Monthly Returns of MSFT  Monthly Returns of NEE  \
# Monthly Returns of CSCO                 0.564646                0.190071
# Monthly Returns of BMY                  0.427358                0.241950
# Monthly Returns of LMT                  0.193327                0.003775
# Monthly Returns of MON                  0.096793                0.015819
# Monthly Returns of PG                   0.322459                0.355241
#
#                          Monthly Returns of GOOG  Monthly Returns of CVS
# Monthly Returns of CSCO                 0.514603                0.378935
# Monthly Returns of BMY                  0.190694                0.491485
# Monthly Returns of LMT                  0.144177                0.476443
# Monthly Returns of MON                  0.159905                0.010603
# Monthly Returns of PG                   0.190129                0.253768

# %%
final_beta_std = []
for stock in total_list:
    final_beta_std.append((final_returns['Monthly Returns of '+stock].std(axis=0,skipna=True),beta_vals["Monthly Returns of "+stock].iloc[0],stock))
final_beta_std.sort()
final_beta_std
# Out:
# [(0.4310261262982297, -0.04813666256123079, 'MON'),
#  (0.7601213194267271, 0.1386584965653855, 'PG'),
#  (0.7688321597213277, 0.4999981723218368, 'KO'),
#  (0.8070678497721255, 0.27208094687927487, 'PEP'),
#  (0.8252266938315554, 0.21284068511016407, 'SO'),
#  (0.8747186606103451, 0.7336717999040371, 'T'),
#  (0.9473982893659325, 0.1479497575862508, 'CL'),
#  (0.9523077719862846, 0.5814648713566358, 'COST'),
#  (0.9653513769944979, 0.8127925379186896, 'LMT'),
#  (1.0195849623485882, 0.4884316944235335, 'BMY'),
#  (1.0335788002409754, 0.786460087670376, 'CSCO'),
#  (1.0415131105322977, 0.36400286927796205, 'ABT'),
#  (1.046658278251328, 0.9955638582968797, 'ACN'),
#  (1.0987572408075144, 1.0660842732172688, 'MSFT'),
#  (1.152816727036022, 0.35793174019028534, 'NEE'),
#  (1.1976737036390077, 1.3367436601444522, 'GOOG'),
#  (1.1998659276253096, 0.8655149801803501, 'CVS'),
#  (1.2247162443231847, 0.8349647502245604, 'SBUX'),
#  (1.636171983361825, 1.672490541016706, 'KMI'),
#  (1.8787728953059228, 1.949598933240963, 'SPG')]

# %%
final_beta_std_dataframe = pd.DataFrame(final_beta_std)
final_beta_std_dataframe.columns = ['Beta', 'Standard Deviation', 'Stock Names']

final_alphas = get_alpha(final_beta_std_dataframe['Stock Names'].tolist())
for stock in final_beta_std_dataframe['Stock Names'].tolist():
    final_alphas['Alpha ' + stock] = final_alphas['Alpha ' + stock].mean()

# Take the first row of the DataFrame
final_alphas = final_alphas.head(1)

# Create a dynamic array that contains all the alpha values
alpha_list = []

# Append all alpha values from the dataframe to the list
for i in range(len(final_alphas.columns)):
    alpha_list.append(final_alphas.iloc[0, i])

alpha_list


final_beta_std_dataframe['Alpha'] = pd.DataFrame(alpha_list)
final_beta_std_dataframe['MDD'] = pd.DataFrame(get_mdd(final_beta_std_dataframe['Stock Names'].tolist()))
final_beta_std_dataframe
# Dynamic Function to Draw Graph

# Set the random list of colours
colours = ['b', 'r', 'c', 'm', 'y', 'k']
plt.figure(figsize=(20, 20))

# Define the function that draws the Graph
def draw_graphs(df):
    for column_name in (df.columns.tolist()):
        if(column_name != 'Stock Names'):
            plt.plot(df['Stock Names'], df[column_name], color = random.choice(colours), label = (column_name))

    plt.legend(loc ='best')
    plt.xlabel('Stock Names')
    plt.xticks(rotation = 70)
    plt.ylabel('Units')
    plt.title('Beta In Relation With Standard Deviation, MDD, and Alpha')

    # Display the graph
    plt.show()

draw_graphs(final_beta_std_dataframe)

# %%
print(get_average_std(total_list))
print(get_beta_total(total_list))
# Out:
# 1.04310800607395
# 0.703455399648219

# %%
# Set the random list of colours
colours = ['b', 'r', 'c', 'm', 'y', 'k']
plt.figure(figsize=(20, 20))

# Define the function that draws the Graph
def draw_graphs(df):
    for column_name in (df.columns.tolist()):
        if(column_name != 'Stock Names'):
            plt.plot(df['Stock Names'], df[column_name], color = random.choice(colours), label = (column_name))

    plt.legend(loc ='best')
    plt.xlabel('Stock Names')
    plt.xticks(rotation = 70)
    plt.ylabel('Units')
    plt.title('Beta In Relation With Standard Deviation, MDD, and Alpha')

    # Display the graph
    plt.show()

# %%
final_beta_std_dataframe = pd.DataFrame(final_beta_std)
final_beta_std_dataframe.columns = ['Beta', 'Standard Deviation', 'Stock Names']
final_beta_std_dataframe['Alpha'] = pd.DataFrame(alpha_list)
final_beta_std_dataframe['MDD'] = pd.DataFrame(get_mdd(final_beta_std_dataframe['Stock Names'].tolist()))
;;final_beta_std_dataframe
# Dynamic Function to Draw Graph



draw_graphs(final_beta_std_dataframe)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MDD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3825         try:
# -> 3826             loc = self._info_axis.get_loc(key)
#    3827         except KeyError:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#
# KeyError: 'MDD'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-5bf417797abe> in <module>
#       2 final_beta_std_dataframe.columns = ['Beta', 'Standard Deviation', 'Stock Names']
#       3 final_beta_std_dataframe['Alpha'] = pd.DataFrame(alpha_list)
# ----> 4 final_beta_std_dataframe['MDD'] = pd.DataFrame(get_mdd(final_beta_std_dataframe['Stock Names'].tolist()))
#       5 final_beta_std_dataframe
#       6 # Dynamic Function to Draw Graph
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3241         self._ensure_valid_index(value)
#    3242         value = self._sanitize_column(key, value)
# -> 3243         NDFrame._set_item(self, key, value)
#    3244
#    3245         # check if we are modifying a copy
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3827         except KeyError:
#    3828             # This item wasn't present, just insert at end
# -> 3829             self._mgr.insert(len(self._info_axis), key, value)
#    3830             return
#    3831
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1201             value = safe_reshape(value, (1,) + value.shape)
#    1202
# -> 1203         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1204
#    1205         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2740         values = DatetimeArray._simple_new(values, dtype=dtype)
#    2741
# -> 2742     return klass(values, ndim=ndim, placement=placement)
#    2743
#    2744
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     140
#     141         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 142             raise ValueError(
#     143                 f"Wrong number of items passed {len(self.values)}, "
#     144                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 2, placement implies 1

# %%
def create_portfolio(stock_list,balance):
    ticker_frame = pd.DataFrame()
    for x in range (len(stock_list)):
        ticker_frame = pd.concat([ticker_frame, pd.DataFrame((hist_data['Close of '+stock_list[x]]*(1/len(stock_list)*balance)/hist_data['Close of '+stock_list[0]])).rename(columns={'Close of '+stock_list[x]:'Value of '+stock_list[x]})], axis=1))
    return ticker_frame
# Out:
#   File "<ipython-input-22-c8f125fe9765>", line 4
#     ticker_frame = pd.concat([ticker_frame, pd.DataFrame((hist_data['Close of '+stock_list[x]]*(1/len(stock_list)*balance)/hist_data['Close of '+stock_list[0]])).rename(columns={'Close of '+stock_list[x]:'Value of '+stock_list[x]})], axis=1))
#                                                                                                                                                                                                                                                  ^
# SyntaxError: unmatched ')'

# %%
## Check the value of the portfolio with all 10,000 dollars invested in it
base_portfolio = create_portfolio(['AAPL'],100000)
base_portfolio['Balance'] = base_portfolio.sum(axis=1)
base_portfolio['Monthly Returns']= base_portfolio['Balance'].pct_change()* 100
## Calculate the sharpe ratio and assign it to a variable
base_value = base_portfolio.mean().loc['Monthly Returns']*base_portfolio.std(axis=0,skipna=True).loc['Monthly Returns']
## Place the sharpe ratio into a list
sharpe_list = [base_value]
## Iterate through weightings 1-100, and calculate the sharpe ratio
new_list = [stock_list[0]]
list_of_weights = [stock_list[0]]
weighted_portfolio = pd.DataFrame()
for x in range (min(len(cleaned_list),20)):
    overall_portfolio = create_portfolio(list_of_weights,new_list,100000)
    new_list.append(stock_list[x])
    for x in range(1,101):
        current_portfolio = pd.concat([create_monthly(overall_portfolio, (10000*x/100)), create_monthly(stock_list[x], (10000*(100-x)/100))],axis=1)
        current_portfolio['Balance'] = current_portfolio.sum(axis=1)
        current_portfolio['Monthly Returns']= current_portfolio['Balance'].pct_change()* 100
        current_value = current_portfolio.mean().loc['Monthly Returns']/current_portfolio.std(axis=0,skipna=True).loc['Monthly Returns']
        ## Add the sharpe ratio to a list
        sharpe_list.append(current_value)
        ## If the sharpe ratio is larger than the current largest one, replace it
        if base_value < current_value:
            ## Take the ideal weighting and store it in a variable
            weighting=x
            base_value = current_value

# %% [markdown]
# ## Contribution Declaration
#
# The following team members made a meaningful contribution to this assignment:
#
# Insert Names Here.
